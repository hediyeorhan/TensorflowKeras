# %%
import tensorflow as tf
from os import path, getcwd, chdir

# %%
def train_mnist_conv():

    mnist = tf.keras.datasets.mnist
    (training_images, training_labels), (test_images, test_labels) = mnist.load_data()
    
    training_images=training_images.reshape(60000, 28, 28, 1)
    training_images=training_images / 255.0

    test_images = test_images.reshape(10000, 28, 28, 1)
    test_images=test_images/255.0

    model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(28, 28, 1)),
     tf.keras.layers.MaxPooling2D(2, 2),
     tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
     tf.keras.layers.MaxPooling2D(2,2),
     tf.keras.layers.Flatten(),
     tf.keras.layers.Dense(128, activation='relu'),
     tf.keras.layers.Dense(10, activation='softmax')
      ])
    
    model.summary()

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
 
    history = model.fit(training_images, training_labels, epochs = 10)
  
    return history.epoch, history.history['acc'][-1]

# %%
_, _ = train_mnist_conv()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 26, 26, 64)        640
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               204928
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 243,786
# Trainable params: 243,786
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/8
# 1875/1875 [==============================] - 81s 43ms/step - loss: 0.1193 - accuracy: 0.9636
# Epoch 2/8
# 1875/1875 [==============================] - 80s 43ms/step - loss: 0.0403 - accuracy: 0.9875
# Epoch 3/8
# 1875/1875 [==============================] - 80s 43ms/step - loss: 0.0267 - accuracy: 0.9921
# Epoch 4/8
# 1875/1875 [==============================] - 80s 43ms/step - loss: 0.0200 - accuracy: 0.9935
# Epoch 5/8
# 1875/1875 [==============================] - 80s 42ms/step - loss: 0.0144 - accuracy: 0.9953
# Epoch 6/8
# 1875/1875 [==============================] - 80s 42ms/step - loss: 0.0113 - accuracy: 0.9962
# Epoch 7/8
# 1875/1875 [==============================] - 80s 42ms/step - loss: 0.0087 - accuracy: 0.9967
# Epoch 8/8
# 1875/1875 [==============================] - 80s 42ms/step - loss: 0.0084 - accuracy: 0.9971
