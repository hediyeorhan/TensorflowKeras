# %%
import tensorflow as tf
from tensorflow import keras

# %%
# GRADED FUNCTION: train_mnist
def train_mnist():
  
    mnist = tf.keras.datasets.mnist

    (x_train, y_train),(x_test, y_test) = mnist.load_data()
    

    x_train = x_train/255.0
    x_test = x_test/255.0

    model = tf.keras.models.Sequential([tf.keras.layers.Flatten(), 
                                        tf.keras.layers.Dense(128, activation=tf.nn.relu),
                                        tf.keras.layers.Dense(10, activation=tf.nn.softmax)
    ])

    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    
 
    model.fit(x_train, y_train, epochs = 8)

# %%
train_mnist()
# Out:
# Epoch 1/8
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2593 - accuracy: 0.9263
# Epoch 2/8
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1128 - accuracy: 0.9664
# Epoch 3/8
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0780 - accuracy: 0.9768
# Epoch 4/8
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0584 - accuracy: 0.9821
# Epoch 5/8
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0457 - accuracy: 0.9857
# Epoch 6/8
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0346 - accuracy: 0.9895
# Epoch 7/8
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0288 - accuracy: 0.9912
# Epoch 8/8
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0233 - accuracy: 0.9928
